# %%
import requests

#AlphaVantage API key
api_key = '8U8OGK31EO6CESRW'

#symbol take the stock which we want the data for
symbol = input("Enter the stock symbol: ")
# Out:
# Enter the stock symbol: AAPL

# %%
#request to fetch data
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={symbol}&apikey={api_key}'

response = requests.get(url)
if response.status_code == 200:
    data = response.json()

    time_series = data['Time Series (Daily)']
    
    for date, info in time_series.items():
        # Access the adjusted close price for each day
        close_price = info['5. adjusted close']
        
        # Print the date and adjusted close price
        print(f"Date: {date}, Adjusted Close Price: {close_price}")

else:
    print(f"Error occurred. Status code: {response.status_code}")
# Out:
# Date: 2023-05-31, Adjusted Close Price: 177.25
# Date: 2023-05-30, Adjusted Close Price: 177.3
# Date: 2023-05-26, Adjusted Close Price: 175.43
# Date: 2023-05-25, Adjusted Close Price: 172.99
# Date: 2023-05-24, Adjusted Close Price: 171.84
# Date: 2023-05-23, Adjusted Close Price: 171.56
# Date: 2023-05-22, Adjusted Close Price: 174.2
# Date: 2023-05-19, Adjusted Close Price: 175.16
# Date: 2023-05-18, Adjusted Close Price: 175.05
# Date: 2023-05-17, Adjusted Close Price: 172.69
# Date: 2023-05-16, Adjusted Close Price: 172.07
# Date: 2023-05-15, Adjusted Close Price: 172.07
# Date: 2023-05-12, Adjusted Close Price: 172.57
# Date: 2023-05-11, Adjusted Close Price: 173.508694519993
# Date: 2023-05-10, Adjusted Close Price: 173.313965337654
# Date: 2023-05-09, Adjusted Close Price: 171.531444360859
# Date: 2023-05-08, Adjusted Close Price: 173.259041722123
# Date: 2023-05-05, Adjusted Close Price: 173.328944505526
# Date: 2023-05-04, Adjusted Close Price: 165.559749435797
# ...

# %%
#news and sentiments data
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={symbol}&apikey={api_key}'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'items': '50', 'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish', 'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.', 'feed': [{'title': "Apple Leverages Tmall, China's Hottest Live Shopping Event for a Chinese Comeback - Alibaba Group Holding  ( NYSE:BABA ) , Apple  ( NASDAQ:AAPL ) ", 'url': 'https://www.benzinga.com/news/23/05/32645873/apple-leverages-tmall-chinas-hottest-live-shopping-event-for-a-chinese-comeback', 'time_published': '20230531T141410', 'authors': ['Anusuya Lahiri'], 'summary': "Apple Inc AAPL prepares for the debut of its live-shopping event on China's Tmall marketplace this week to tap over 500 million users in the leading internet market.", 'banner_image': 'https://cdn.benzinga.com/files/images/story/2023/05/31/iphone_14_yellow.jpg?width=1200&height=800&fit=crop', 'source': 'Benzinga', 'category_with
# ...
